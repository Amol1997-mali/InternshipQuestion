# %% [markdown]
# a. List the areas you would look into when it comes to data preparation
# b. Highlight any data idiosyncrasies that you might have observed
# c. Put together a short presentation/document to tell a story about the key insights and
# observations, taking into consideration dataset limitations.

# %% [markdown]
# List the areas you would look into when it comes to data preparation
# Ans:
# For data preparation I would like into consider variables purpose, occupation, shopping, accomdation,traveling mode.

# %% [markdown]
# b. Highlight any data idiosyncrasies that you might have observed.
# Ans:
# From this data it shows the tendency of the visitors from a country Indonesia.

# %%
c. Put together a short presentation/document to tell a story about the key insights and
observations, taking into consideration dataset limitations.
Ans:
link: https://public.tableau.com/views/Internshipwork2/Story1?:language=en&:display_count=y&publish=yes&:origin=viz_share_link

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel('C:/Internship2/MockSurveyData.xlsx')

# %%
data.head(20)
# Out:
#     case  Year    R.mth       date      intv_nam Country_residence  \
# 0     18  2015  January 2015-01-01     Cindy Liu         Indonesia
# 1     41  2015  January 2015-01-01   Philip Chew         Indonesia
# 2     43  2015  January 2015-01-01   Philip Chew         Indonesia
# 3     44  2015  January 2015-01-01   Philip Chew         Indonesia
# 4     45  2015  January 2015-01-01   Philip Chew         Indonesia
# 5     46  2015  January 2015-01-01   Philip Chew         Indonesia
# 6     47  2015  January 2015-01-01   Philip Chew         Indonesia
# 7     49  2015  January 2015-01-01   Philip Chew         Indonesia
# 8     50  2015  January 2015-01-01   Philip Chew         Indonesia
# 9     51  2015  January 2015-01-01   Philip Chew         Indonesia
# 10    52  2015  January 2015-01-01   Philip Chew         Indonesia
# 11    53  2015  January 2015-01-01   Philip Chew         Indonesia
# 12    54  2015  January 2015-01-01   Philip Chew         Indonesia
# ...

# %%
data.describe()
# Out:
#                case         Year  Weights_QTR    shop_$fash     shop_$jew  \
# count   8887.000000  8887.000000  8887.000000   8807.000000   8807.000000
# mean   11521.140880  2014.503545   592.199788     84.202886      4.073048
# std     6615.259259     0.500016   352.449669    347.318349    124.264357
# min       15.000000  2014.000000     0.000000      0.000000      0.000000
# 25%     5623.500000  2014.000000   419.090000      0.000000      0.000000
# 50%    11381.000000  2015.000000   534.883333      0.000000      0.000000
# 75%    17418.500000  2015.000000   666.422535     70.000000      0.000000
# max    23243.000000  2015.000000  8958.000000  15000.000000  10000.000000
#
#          shop_$wat   shop_$well   shop_$food   shop_$gift   shop_$ctec  ...  \
# count  8807.000000  8807.000000  8807.000000  8807.000000  8807.000000  ...
# mean      5.078301    19.603905    23.220032     7.454479    13.223605  ...
# ...

# %%
data['intv_nam'].unique()
# Out:
# array(['Cindy Liu', 'Philip Chew', 'Bay Poh Choo', 'Simon', 'Shariffah',
#        'Adwen', 'Noraini', 'Teck Ghee', 'Anderson Yu Tor Kim', 'Bhadrul',
#        'Chris', 'Felicia', 'Nizam', 'Patrick lim', 'Jay', 'CI', 'PC',
#        'S1', 'And', 'Patrick Lim', 'Anees', 'Joeypoh', 'Cl', 'Sharon Hsu',
#        'Sarah', 'Angeline Cheong', 'Shanon Lim', 'Cindy Lim', 'Sharrifah',
#        'BAY POH CHOO', 'Cindy liu', 'Meri', 'Janelle', 'Cindy Pang'],
#       dtype=object)

# %%
data['Country_residence'].unique()
# Out:
# array(['Indonesia'], dtype=object)

# %%
data['Purpose_grp'].unique()
# Out:
# array(['Leisure', 'Others/ Refused', 'Healthcare+Accompanying Pax',
#        'Business+Accompanying Pax', 'Education+Accompanying Pax'],
#       dtype=object)

# %%
data['Purpose'].unique()
# Out:
# array(['Holiday/ Rest & Relax', 'Others',
#        'Others - Personal (e.g. weddings, funerals, etc)',
#        'Visiting friends/relatives',
#        'To take or join a regional or international cruise',
#        'Outpatient consultation/treatment',
#        'Visiting an international student studying in Singapore',
#        'Accompanying a Healthcare/medical visitor for Outpatient consultation/treat',
#        'General business purpose', 'Sightseeing/ Attractions', 'Stopover',
#        'Others - Work Related (e.g. visa, insurance, etc)',
#        'Student events', 'To shop/attend shopping events in Singapore',
#        'Company sponsored holiday',
#        'Executive training, including training workshops and seminar',
#        'Corporate/business meetings', 'IR (e.g. MBS, RWS)',
#        'Convention/conference',
#        'Skills development/skills training/vocational training',
#        'Exhibition/Trade show', 'In-patient treatment',
# ...

# %%
data['Air_Terminal'].unique()
# Out:
# array(['Terminal 1', nan, 'Terminal 2', 'Terminal 3'], dtype=object)

# %%
data['Land_Terminal'].unique()
# Out:
# array([nan, 'Tuas', 'Woodlands'], dtype=object)

# %%
data['Sea_Terminal'].unique()
# Out:
# array([nan, 'RFT', 'MBCCS', 'TMFT', 'HCC'], dtype=object)

# %%
data['langint'].unique()
# Out:
# array(['English', 'Chinese', 'Malay', 'Hybrid Chinese', 'Indonesian',
#        'Hybrid Indonesian', 'Japanese', 'Hybrid French'], dtype=object)

# %%
data['length_stay'].unique()
# Out:
# array(['4 days', '2 days', '3 days', '1 day', '5 days', 'Under 1 day',
#        '8-10 days', '6 days', '7 days', '15-29 days', '11-14 days',
#        '30-59 days', '60 days & over'], dtype=object)

# %%
data['shop_$oth'].unique()
# Out:
# array([0.00000000e+00, 3.60000000e+01, 7.50000000e+00, 3.00000000e+01,
#                   nan, 8.50000000e+01, 1.00000000e+02, 2.00000000e+02,
#        1.25000000e+02, 1.30000000e+02, 5.00000000e+01, 2.20000000e+02,
#        1.00000000e+01, 1.50000000e+02, 2.25000000e+01, 4.45000000e+01,
#        1.00000000e+00, 1.15000000e+02, 2.70000000e+01, 2.65000000e+01,
#        2.40000000e+01, 7.00000000e+01, 6.00000000e+02, 6.66666667e+01,
#        1.89000000e+02, 6.00000000e+01, 8.00000000e+01, 2.00000000e+01,
#        6.30000000e+01, 2.14285714e+01, 2.20000000e+01, 3.50000000e+01,
#        4.50000000e+01, 7.50000000e+01, 4.00000000e+01, 2.50000000e+01,
#        5.00000000e+00, 1.60000000e+02, 1.75000000e+01, 2.33333333e+01,
#        1.80000000e+01, 7.10000000e+01, 3.20000000e+01, 1.50000000e+01,
#        1.60000000e+01, 2.50000000e+02, 2.72727273e+00, 1.06666667e+01,
#        3.00000000e+02, 1.08000000e+02, 3.19000000e+02, 1.90000000e+01,
# ...

# %%
data['travel_companion.1'].unique()
# Out:
# array(['Spouse', 'Partner/ Boyfriend/ Girlfriend',
#        'Parents/ Parents-in-law', 'Friends', 'Alone', 'Siblings',
#        'Others', 'Children aged 8-12 yrs', 'Children aged 20-39 yrs',
#        'Business associates/ Colleagues', 'Children aged 13-19 yrs',
#        'Other relatives', 'Children aged 0-7 yrs',
#        'Grandparents/ Grandparents-in-law',
#        'Children aged 40 yrs and above'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8887 entries, 0 to 8886
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case                8887 non-null   int64
#  1   Year                8887 non-null   int64
#  2   R.mth               8887 non-null   object
#  3   date                8887 non-null   datetime64[ns]
#  4   intv_nam            8887 non-null   object
#  5   Country_residence   8887 non-null   object
#  6   City_residence      8887 non-null   object
#  7   Purpose_grp         8887 non-null   object
#  8   Purpose             8887 non-null   object
#  9   Weights_QTR         8887 non-null   float64
#  10  Air_Terminal        5697 non-null   object
#  11  Sea_Terminal        2828 non-null   object
#  12  Land_Terminal       355 non-null    object
#  13  langint             8887 non-null   object
#  14  1st_visit           8887 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# case                     0
# Year                     0
# R.mth                    0
# date                     0
# intv_nam                 0
# Country_residence        0
# City_residence           0
# Purpose_grp              0
# Purpose                  0
# Weights_QTR              0
# Air_Terminal          3190
# Sea_Terminal          6059
# Land_Terminal         8532
# langint                  0
# 1st_visit                0
# length_stay              0
# travel_type              0
# f1_gender                0
# f3_occupation            0
# f4_industry           2844
# f5_designation        3096
# f5_designation.oth    2969
# shop_$fash              80
# shop_$jew               80
# shop_$wat               80
# shop_$well              80
# shop_$food              80
# shop_$gift              80
# shop_$ctec              80
# shop_$anti              80
# shop_$oth               80
# shop_$any               80
# totacc_$                 0
# totfnb_$                 0
# ...

# %%
data['case'].describe()
# Out:
# count     8887.000000
# mean     11521.140880
# std       6615.259259
# min         15.000000
# 25%       5623.500000
# 50%      11381.000000
# 75%      17418.500000
# max      23243.000000
# Name: case, dtype: float64

# %%
data.shape
# Out:
# (8887, 48)
